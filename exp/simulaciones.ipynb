# %%
def correr_simu(nombre, args):
    cookiecutter_args = ' '.join(['{}={}'.format(k, v) for (k,v) in args.items()])
    # !./run.sh $nombre_exp $cookiecutter_args

# %% [markdown]
# ## Instrucciones
#
# Para correr una simulación, usar el método *correr_simu* especificando un nombre y un diccionario con parámetros. Los parámetros que se pueden mandar son los que aparecen en el archivo **cookiecutter.json**. Los que no se especifican explicitamente, se toman por los valores por default definidos ahí.
#
# El resultado de correr el método va a ser una carpeta nueva con el nombre de la simulación y toda la data relevante (top.ma, top.val, logs)

# %%
for i in [2,4,6,8,10]:
    nombre_exp = 'exp-imp-{}'.format(i)
    correr_simu(nombre_exp, {
        'impuestos_local': i
    })
# Out:
# PCD++: A Tool to Implement n-Dimensional Cell-DEVS models
# Version 3.0 - March 2003
# Troccoli A., Rodriguez D., Wainer G., Barylko A., Beyoglonian J., Lopez A.
# -----------------------------------------------------------------------------
# PCD++ Extended States: An extended and improved version of CD++ for Cell-DEVS
# Version 4.1.2 - December 2018
# Santi L., Castro, R., Pimás, J.
# -----------------------------------------------------------------------------
# Discrete Event Simulation Lab
# Departamento de Computación
# Facultad de Ciencias Exactas y Naturales
# Universidad de Buenos Aires, Argentina
# -----------------------------------------------------------------------------
# Compiled for standalone simulation
#
#
# Loading models from top.ma
# Loading events from
# Running parallel simulation. Reading models partition from
# Model partition details output to: /dev/null*
# Message log: logs
# Output to: /dev/null
# Tolerance set to: 1e-08
# ...
